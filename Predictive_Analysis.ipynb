# %% [markdown]
# <a href="https://colab.research.google.com/github/Vardhan1627/DA-WITH-PYTHON/blob/main/Predictive_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.DataFrame({"Water_Consumption":[143,234,454,234,123],
                 "Days":["Monday","Tuesday","Wednesday","Thrsday","Friday",]})
print(df)
avg_of_water=df["Water_Consumption"].mean()
print("Avg_Water:",avg_of_water)
total_water_usage=df["Water_Consumption"].sum()
print("Water_Usage:",total_water_usage)
# Calculate the number of days as an integer count, as was done previously.
sum_of_days=len(df)
print("No_Of_Days:",sum_of_days)
avg_water_usage=total_water_usage/sum_of_days
print("Avg_Water_Usage:",avg_water_usage)
shortage_water=avg_of_water-avg_water_usage
print("Shortage_water:",shortage_water)
# Out:
#    Water_Consumption       Days
# 0                143     Monday
# 1                234    Tuesday
# 2                454  Wednesday
# 3                234    Thrsday
# 4                123     Friday
# Avg_Water: 237.6
# Water_Usage: 1188
# No_Of_Days: 5
# Avg_Water_Usage: 237.6
# Shortage_water: 0.0

# %%
plt.bar(df["Days"],df["Water_Consumption"])
plt.xlabel("Days")
plt.ylabel("Water Consumption")
plt.title("Water Consumption by Day")
plt.show()

# %%
plt.pie(df["Water_Consumption"],labels=df["Days"],autopct="%1.1f%%")
plt.title("Water Consumption by Day")
plt.show()

# %%
plt.hist(df["Water_Consumption"])
plt.xlabel("Water Consumption")
plt.ylabel("Frequency")
plt.title("Water Consumption Histogram")
plt.show()

# %%
plt.boxplot(df["Water_Consumption"])
plt.xlabel("Water Consumption")
plt.title("Water Consumption Box Plot")
plt.show()

# %% [markdown]
# **By Using Dataset From Kaggle**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/AguaH.csv", engine='python')
print(df)
# Out:
#        USO2013                     TU   DC                M      UL  \
# 0           H3        DOMESTICO MEDIO  0.5       MSDELAUNET   197.0
# 1           H3        DOMESTICO MEDIO  0.5       MSDELAUNET   307.0
# 2           H3  DOMESTICO RESIDENCIAL  0.5       MSDELAUNET   179.0
# 3           H3        DOMESTICO MEDIO  0.5  CICASA MMD-15 S   852.0
# 4           H3  DOMESTICO RESIDENCIAL  0.5              NaN     NaN
# ...        ...                    ...  ...              ...     ...
# 178592     RHC              COMERCIAL  3.0            ADCOM  6614.0
# 178593      MX              COMERCIAL  3.0            ADCOM  6614.0
# 178594     RHC              COMERCIAL  3.0            ADCOM  6614.0
# 178595      MX              COMERCIAL  3.0            ADCOM  6614.0
# 178596      MX              COMERCIAL  3.0            ADCOM  6614.0
#
#         f.1_ENE_09  f.1_FEB_09  f.1_MAR_09  f.1_ABR_09  f.1_MAY_09  ...  \
# 0             20.0        20.0        20.0        20.0        20.0  ...
# ...

# %%
plt.figure(figsize=(8,5))
sns.histplot(df[water_col], bins=20, kde=True)
plt.title("Water Consumption Distribution")
plt.xlabel("Water Consumption")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(df.index, df[water_col])
plt.title("Water Consumption vs. Index")
plt.xlabel("Index")
plt.ylabel("Water Consumption")
plt.show()

# %%
top10 = df[water_col].nlargest(10)

plt.figure(figsize=(10,5))
top10.plot(kind='bar')
plt.title("Top 10 Highest Water Consumption Days")
plt.xlabel("Day Index")
plt.ylabel("Water Consumption")
plt.show()

# %%
plt.plot(df["f.1_ENE_09"])
plt.title("Water Consumption (f.1_ENE_09) Trend")
plt.xlabel("Index")
plt.ylabel("Water Consumption")
plt.show()

# %%
plt.plot(df["f.1_ENE_10"])
plt.title("Water Consumption (f.1_ENE_10) Trend")
plt.xlabel("Index")
plt.ylabel("Water Consumption")
plt.show()

# %%
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title("Water Consumption Distribution (Categorized)")
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
